# %%
import functools
import multiprocessing as mp
import re
import os
from keras.preprocessing import image
import PIL.Image
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model
import numpy as np
from collections import OrderedDict
from sklearn.decomposition import PCA
from scipy.spatial import distance
from scipy.cluster import hierarchy
import shutil
# Out:
# Using TensorFlow backend.

# %%
pj = os.path.join

# %%
def get_files(dr, ext='jpg|jpeg|bmp|png'):
    rex = re.compile(r'^.*\.({})$'.format(ext), re.I)
    return [os.path.join(dr,base) for base in os.listdir(dr) if rex.match(base)]

# %%
def _img_worker(fn, size):
    return fn, image.img_to_array(PIL.Image.open(fn).resize(size, 3))

# %%
def image_array(data_path, size):
    _f = functools.partial(_img_worker, size=size)
    with mp.Pool(mp.cpu_count()) as pool:
        ret = pool.map(_f, get_files(data_path))
    return dict(ret)

# %%
def get_model(layer='fc2'):
    base_model = VGG16(weights='imagenet', include_top=True)
    #base_model.summary()
    model = Model(inputs=base_model.input, outputs=base_model.get_layer(layer).output)
    #model.summary()
    return model

# %%
def fingerprint(img_arr, model):
    if img_arr.shape[2] == 1:
        img_arr = img_arr.repeat(3, axis=2)
        
    arr4d = np.expand_dims(img_arr, axis=0)
    arr4d_pp = preprocess_input(arr4d)
    return model.predict(arr4d_pp)[0,:]

# %%
def fingerprints(ias, model):
    fps = {}
    for fn, img_arr in ias.items():
        fps[fn] = fingerprint(img_arr, model)
        
    return fps

# %%
def pca(fps, n_components=0.9, **kwds):
    if 'n_components' not in kwds.keys():
        kwds['n_components'] = n_components
    _fps = OrderedDict(fps)
    X = np.array(list(_fps.values()))
    if X.shape[0] == 0:
        return -1
    XP = PCA(**kwds).fit(X).transform(X)
    return {k:v for k, v in zip(_fps.keys(), XP)}

# %%
def cluster_stats(clusters):
    return np.array([[k, len(clusters[k])] for k in np.sort(list(clusters.keys()))], dtype=int)

# %%
def print_cluster_stats(clusters):
    print("#images : #clusters")
    stats = cluster_stats(clusters)
    for csize, cnum in stats:
        print(f"{csize} : {cnum}")
    if stats.shape[0] > 0:
        nimg = stats.prod(axis=1).sum()
    else:
        nimg = 0
    print("#images in clusters total: ", nimg)

# %%
def cluster(fps, sim=0.5, method='average', metric='euclidean', extra_out=False, print_stats=True, min_csize=2):
    assert 0 <= sim <= 1
    assert min_csize >= 1
    files = list(fps.keys())
    
    dfps = distance.pdist(np.array(list(fps.values())), metric)
    Z = hierarchy.linkage(dfps, method=method, metric=metric)
    cut = hierarchy.fcluster(Z, t=dfps.max()*(1.0*sim), criterion='distance')
    cluster_dict = dict((ii, []) for ii in np.unique(cut))
    for iimg, iclus in enumerate(cut):
        cluster_dict[iclus].append(files[iimg])
        
    clusters = {}
    for cluster in cluster_dict.values():
        csize = len(cluster)
        if csize >= min_csize:
            if not (csize in clusters.keys()):
                clusters[csize] = [cluster]
            else:
                clusters[csize].append(cluster)
                
    if print_stats:
        print_cluster_stats(clusters)
    if extra_out:
        extra={'Z':Z, 'dfps': dfps, 'cluster_dict': cluster_dict, 'cut':cut}
        return clusters, extra
    else:
        return clusters

# %%
def make_links(clusters, cluster_dir):
    print("cluster dir: {}".format(cluster_dir))
    if os.path.exists(cluster_dir):
        shutil.rmtree(cluster_dir)
    for csize, group in clusters.items():
        for iclus, cluster in enumerate(group):
            dr = pj(cluster_dir, 'cluster_with_{}'.format(csize), 'cluster_{}'.format(iclus))
            for fn in cluster:
                link = pj(dr, os.path.basename(fn))
                os.makedirs(os.path.dirname(link), exist_ok=True)
                os.symlink(os.path.abspath(fn), link)

# %%
data_path = '/mnt/disks/slow1/video_processing/frames/Luarent_data/'
size = (224, 224)
model = get_model()

for sub_fold in os.listdir(data_path):
    sub_path = data_path + sub_fold
    print(sub_path)
    for sub_sub_fold in os.listdir(sub_path):
        sub_sub_path = sub_path + '/' + sub_sub_fold
        print(sub_sub_path)

        ias = image_array(sub_sub_path, size)

        fps = fingerprints(ias, model)
        
        fps = pca(fps, n_components=0.95)
        if fps != -1:
            clusters = cluster(fps, sim=0.5)
        
            make_links(clusters, sub_sub_path+'/imagecluster/clusters')
# Out:
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000106
# #images : #clusters
# 52 : 1
# 78 : 1
# 120 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000106/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000104
# #images : #clusters
# 3 : 1
# 6 : 1
# 9 : 1
# 16 : 1
# 49 : 1
# 167 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000104/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000054
# #images : #clusters
# 15 : 1
# 37 : 1
# 41 : 1
# 59 : 1
# 98 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000054/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000008
# #images : #clusters
# 7 : 1
# 14 : 1
# 23 : 1
# 30 : 1
# 32 : 1
# 33 : 1
# 36 : 2
# 38 : 1
# #images in clusters total:  249
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000008/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000059imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000089
# #images : #clusters
# 9 : 1
# 28 : 1
# 102 : 1
# 111 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000089/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000028imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000107
# #images : #clusters
# 118 : 1
# 132 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000107/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000028
# #images : #clusters
# 19 : 1
# 30 : 1
# 53 : 1
# 148 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000028/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000051
# #images : #clusters
# 6 : 1
# 11 : 1
# 15 : 1
# 25 : 1
# 84 : 1
# 109 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000051/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000117
# #images : #clusters
# 4 : 1
# 54 : 1
# 96 : 2
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000117/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000059
# #images : #clusters
# 26 : 1
# 35 : 1
# 60 : 1
# 129 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000059/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000073
# #images : #clusters
# 6 : 1
# 52 : 1
# 79 : 1
# 113 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000073/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000024
# #images : #clusters
# 47 : 1
# 78 : 1
# 125 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000024/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000013
# #images : #clusters
# 5 : 1
# 53 : 1
# 70 : 1
# 122 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000013/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000045
# #images : #clusters
# 16 : 2
# 24 : 1
# 36 : 1
# 78 : 1
# 80 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000045/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000112
# #images : #clusters
# 2 : 1
# 4 : 1
# 37 : 1
# 55 : 1
# 58 : 1
# 94 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000112/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000097
# #images : #clusters
# 28 : 1
# 52 : 1
# 66 : 1
# 104 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000097/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000081
# #images : #clusters
# 3 : 1
# 55 : 1
# 192 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000081/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000108
# #images : #clusters
# 31 : 1
# 47 : 1
# 172 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000108/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000031
# #images : #clusters
# 12 : 1
# 14 : 1
# 28 : 1
# 36 : 2
# 124 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000031/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000048
# #images : #clusters
# 71 : 1
# 86 : 1
# 93 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000048/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/
: 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000040/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000020
# #images : #clusters
# 10 : 1
# 20 : 1
# 38 : 2
# 68 : 1
# 76 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000020/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000101
# #images : #clusters
# 20 : 1
# 37 : 1
# 48 : 1
# 71 : 1
# 74 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000101/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000012
# #images : #clusters
# 35 : 1
# 48 : 1
# 55 : 1
# 112 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000012/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000069
# #images : #clusters
# 6 : 1
# 7 : 1
# 31 : 1
# 59 : 1
# 70 : 1
# 77 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000069/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000088
# #images : #clusters
# 17 : 1
# 19 : 1
# 88 : 1
# 126 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000088/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000006
# #images : #clusters
# 4 : 1
# 8 : 1
# 9 : 1
# 10 : 1
# 14 : 1
# 20 : 1
# 22 : 2
# 23 : 1
# 26 : 1
# 29 : 2
# 34 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000006/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000017
# #images : #clusters
# 2 : 1
# 21 : 1
# 32 : 1
# 33 : 1
# 57 : 1
# 105 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000017/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000108imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000066
# #images : #clusters
# 37 : 1
# 213 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000066/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000026
# #images : #clusters
# 41 : 1
# 43 : 1
# 69 : 1
# 97 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000026/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000009
# #images : #clusters
# 4 : 1
# 24 : 1
# 32 : 1
# 37 : 1
# 58 : 1
# 95 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000009/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000067
# #images : #clusters
# 47 : 1
# 81 : 1
# 122 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000067/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000084
# #images : #clusters
# 52 : 1
# 198 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000084/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000085
# #images : #clusters
# 3 : 1
# 9 : 2
# 18 : 1
# 40 : 1
# 58 : 1
# 113 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000085/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000014
# #images : #clusters
# 81 : 1
# 83 : 1
# 86 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000014/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000043
# #images : #clusters
# 45 : 1
# 66 : 1
# 139 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000043/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000002
# #images : #clusters
# 16 : 1
# 63 : 1
# 79 : 1
# 92 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000002/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000033
# #images : #clusters
# 64 : 1
# 86 : 1
# 100 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000033/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000054imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000065
# #images : #clusters
# 46 : 1
# 48 : 1
# 50 : 1
# 106 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000065/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000078
# #images : #clusters
# 34 : 1
# 51 : 1
# 80 : 1
# 85 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000078/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000079
# #images : #clusters
# 73 : 1
# 87 : 1
# 90 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000079/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000035
# #images : #clusters
# 33 : 1
# 108 : 1
# 109 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000035/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000021
# #images : #clusters
# 15 : 1
# 18 : 1
# 84 : 1
# 133 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000021/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000008imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000095
# #images : #clusters
# 12 : 1
# 30 : 1
# 87 : 1
# 121 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000095/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000119
# #images : #clusters
# 40 : 1
# 71 : 1
# 75 : 1
# #images in clusters total:  186
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000119/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000018
# #images : #clusters
# 7 : 1
# 11 : 1
# 12 : 1
# 13 : 1
# 18 : 1
# 21 : 1
# 31 : 1
# 56 : 1
# 81 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000018/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000036
# #images : #clusters
# 34 : 1
# 42 : 1
# 52 : 1
# 122 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000036/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000049
# #images : #clusters
# 19 : 1
# 33 : 1
# 91 : 1
# 107 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000049/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000087
# #images : #clusters
# 6 : 1
# 10 : 1
# 17 : 1
# 23 : 2
# 28 : 1
# 44 : 1
# 46 : 1
# 53 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000087/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000111
# #images : #clusters
# 3 : 1
# 4 : 1
# 6 : 1
# 7 : 1
# 8 : 1
# 9 : 1
# 22 : 1
# 47 : 1
# 59 : 1
# 85 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000111/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000070
# #images : #clusters
# 11 : 1
# 53 : 1
# 55 : 1
# 57 : 1
# 74 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000070/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000041
# #images : #clusters
# 29 : 1
# 30 : 1
# 51 : 1
# 140 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000041/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000019
# #images : #clusters
# 13 : 1
# 18 : 1
# 38 : 1
# 58 : 1
# 123 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000019/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000097imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000062
# #images : #clusters
# 2 : 1
# 50 : 1
# 51 : 1
# 147 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000062/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000053
# #images : #clusters
# 3 : 1
# 84 : 1
# 163 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000053/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000039
# #images : #clusters
# 16 : 1
# 20 : 1
# 34 : 1
# 180 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000039/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000029
# #images : #clusters
# 10 : 1
# 11 : 1
# 39 : 1
# 79 : 1
# 111 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000029/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000116
# #images : #clusters
# 14 : 1
# 44 : 1
# 96 : 2
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000116/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000117imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000109
# #images : #clusters
# 55 : 1
# 57 : 1
# 64 : 1
# 74 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000109/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000064imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000089imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000074
# #images : #clusters
# 4 : 1
# 10 : 2
# 11 : 1
# 17 : 1
# 19 : 1
# 20 : 1
# 34 : 1
# 55 : 1
# 70 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000074/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000001
# #images : #clusters
# 39 : 1
# 66 : 1
# 145 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000001/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000056
# #images : #clusters
# 70 : 1
# 81 : 1
# 99 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000056/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000103
# #images : #clusters
# 33 : 1
# 39 : 1
# 87 : 1
# 91 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000103/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000073imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000107imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000083
# #images : #clusters
# 50 : 1
# 88 : 1
# 112 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000083/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000037
# #images : #clusters
# 22 : 1
# 44 : 1
# 66 : 1
# 118 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000037/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000004
# #images : #clusters
# 110 : 1
# 140 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000004/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000114
# #images : #clusters
# 3 : 1
# 7 : 1
# 8 : 1
# 10 : 1
# 13 : 1
# 16 : 1
# 22 : 1
# 29 : 1
# 142 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000114/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000015
# #images : #clusters
# 21 : 1
# 25 : 1
# 76 : 1
# 128 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000015/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000106imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000105
# #images : #clusters
# 10 : 1
# 24 : 1
# 99 : 1
# 117 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000105/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000082
# #images : #clusters
# 48 : 1
# 202 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000082/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000092
# #images : #clusters
# 101 : 1
# 149 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000092/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000057
# #images : #clusters
# 7 : 1
# 10 : 1
# 11 : 1
# 18 : 1
# 22 : 1
# 24 : 1
# 52 : 1
# 106 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000057/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000022
# #images : #clusters
# 2 : 1
# 4 : 1
# 8 : 1
# 12 : 1
# 17 : 1
# 25 : 1
# 29 : 1
# 66 : 1
# 87 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000022/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000072
# #images : #clusters
# 6 : 1
# 9 : 2
# 10 : 1
# 11 : 1
# 25 : 1
# 30 : 1
# 57 : 1
# 93 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000072/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000113
# #images : #clusters
# 12 : 1
# 42 : 1
# 45 : 1
# 151 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000113/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000081imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000000
# #images : #clusters
# 42 : 1
# 48 : 1
# 65 : 1
# 95 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000000/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000051imagecluster
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000102
# #images : #clusters
# 36 : 1
# 88 : 1
# 126 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000102/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000091
# #images : #clusters
# 20 : 1
# 63 : 1
# 64 : 1
# 103 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000091/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000068
# #images : #clusters
# 22 : 1
# 46 : 1
# 182 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000068/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000047
# #images : #clusters
# 7 : 1
# 78 : 1
# 165 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/000047/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112203/
imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000024
# #images : #clusters
# 29 : 1
# 56 : 1
# 165 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000024/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000013
# #images : #clusters
# 2 : 1
# 8 : 1
# 21 : 1
# 27 : 1
# 34 : 1
# 40 : 1
# 118 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000013/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000045
# #images : #clusters
# 6 : 2
# 7 : 2
# 11 : 3
# 13 : 1
# 14 : 1
# 16 : 1
# 29 : 1
# 32 : 1
# 41 : 1
# 46 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000045/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000112
# #images : #clusters
# 15 : 1
# 16 : 1
# 22 : 1
# 25 : 1
# 49 : 1
# 56 : 1
# 67 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000112/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000097
# #images : #clusters
# 17 : 1
# 22 : 1
# 88 : 1
# 123 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000097/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000081
# #images : #clusters
# 5 : 2
# 8 : 2
# 9 : 1
# 10 : 1
# 11 : 1
# 20 : 1
# 31 : 1
# 38 : 1
# 103 : 1
# #images in clusters total:  248
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000081/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000108
# #images : #clusters
# 3 : 1
# 8 : 2
# 9 : 1
# 18 : 1
# 26 : 1
# 44 : 1
# 134 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000108/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000031
# #images : #clusters
# 41 : 1
# 209 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000031/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000048
# #images : #clusters
# 7 : 1
# 70 : 1
# 173 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000048/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000010
# #images : #clusters
# 18 : 1
# 23 : 1
# 25 : 1
# 33 : 2
# 56 : 1
# 62 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000010/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000129
# #images : #clusters
# 2 : 1
# 3 : 1
# 5 : 3
# 15 : 1
# 29 : 1
# 30 : 1
# 57 : 1
# 99 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000129/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000064
# #images : #clusters
# 6 : 1
# 20 : 1
# 25 : 1
# 68 : 1
# 131 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000064/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000080
# #images : #clusters
# 4 : 1
# 7 : 1
# 15 : 1
# 41 : 1
# 91 : 1
# 92 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000080/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000118
# #images : #clusters
# 16 : 1
# 21 : 1
# 32 : 1
# 38 : 1
# 70 : 1
# 73 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000118/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000122
# #images : #clusters
# 21 : 1
# 229 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000122/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000063
# #images : #clusters
# 27 : 1
# 30 : 1
# 42 : 1
# 61 : 1
# 90 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000063/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000005
# #images : #clusters
# 18 : 1
# 32 : 1
# 78 : 1
# 122 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000005/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000050
# #images : #clusters
# 2 : 1
# 44 : 1
# 47 : 1
# 50 : 1
# 107 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000050/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000046
# #images : #clusters
# 7 : 1
# 10 : 1
# 14 : 1
# 19 : 1
# 33 : 1
# 66 : 1
# 101 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000046/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000126
# #images : #clusters
# 6 : 1
# 51 : 1
# 72 : 1
# 121 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000126/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000030
# #images : #clusters
# 14 : 2
# 18 : 1
# 23 : 1
# 24 : 1
# 32 : 1
# 125 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000030/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000060
# #images : #clusters
# 3 : 1
# 5 : 1
# 16 : 1
# 36 : 1
# 38 : 1
# 63 : 1
# 88 : 1
# #images in clusters total:  249
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000060/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000077
# #images : #clusters
# 57 : 1
# 90 : 1
# 103 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000077/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000023
# #images : #clusters
# 20 : 1
# 34 : 1
# 58 : 1
# 138 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000023/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000131
# #images : #clusters
# 30 : 1
# #images in clusters total:  30
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000131/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000025
# #images : #clusters
# 6 : 2
# 7 : 1
# 8 : 1
# 14 : 1
# 26 : 1
# 33 : 1
# 50 : 1
# 100 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/000025/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/112206/
: 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000011/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000038
# #images : #clusters
# 3 : 2
# 5 : 1
# 6 : 1
# 8 : 1
# 9 : 2
# 12 : 3
# 15 : 1
# 16 : 1
# 22 : 1
# 31 : 1
# 38 : 1
# 49 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000038/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000221
# #images : #clusters
# 7 : 1
# 16 : 1
# 88 : 1
# 139 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000221/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000259
# #images : #clusters
# 28 : 1
# 81 : 1
# 141 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000259/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000032
# #images : #clusters
# 58 : 1
# 80 : 1
# 112 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000032/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000169
# #images : #clusters
# 122 : 1
# 128 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000169/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000266
# #images : #clusters
# 8 : 1
# 48 : 1
# 92 : 1
# 102 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000266/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000155
# #images : #clusters
# 92 : 1
# 158 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000155/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000016
# #images : #clusters
# 20 : 1
# 21 : 1
# 24 : 1
# 31 : 1
# 36 : 1
# 49 : 1
# 69 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000016/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000176
# #images : #clusters
# 11 : 1
# 93 : 1
# 146 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000176/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000128
# #images : #clusters
# 12 : 1
# 90 : 1
# 148 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000128/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000044
# #images : #clusters
# 4 : 1
# 78 : 1
# 83 : 1
# 85 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000044/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000124
# #images : #clusters
# 59 : 1
# 191 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000124/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000003
# #images : #clusters
# 2 : 1
# 25 : 1
# 28 : 1
# 53 : 1
# 68 : 1
# 74 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000003/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000099
# #images : #clusters
# 31 : 1
# 219 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000099/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000090
# #images : #clusters
# 12 : 1
# 31 : 1
# 52 : 1
# 56 : 1
# 99 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000090/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000191
# #images : #clusters
# 6 : 1
# 13 : 1
# 16 : 1
# 28 : 1
# 53 : 1
# 134 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000191/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000140
# #images : #clusters
# 30 : 1
# 59 : 1
# 161 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000140/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000007
# #images : #clusters
# 7 : 1
# 11 : 1
# 14 : 1
# 19 : 1
# 32 : 1
# 34 : 1
# 35 : 1
# 38 : 1
# 60 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000007/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000146
# #images : #clusters
# 4 : 1
# 7 : 1
# 21 : 1
# 22 : 1
# 25 : 1
# 40 : 1
# 131 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000146/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000100
# #images : #clusters
# 23 : 1
# 41 : 1
# 186 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000100/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000183
# #images : #clusters
# 31 : 1
# 103 : 1
# 116 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000183/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000166
# #images : #clusters
# 47 : 1
# 69 : 1
# 134 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000166/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000094
# #images : #clusters
# 25 : 1
# 103 : 1
# 122 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000094/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000160
# #images : #clusters
# 21 : 1
# 57 : 1
# 172 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000160/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000086
# #images : #clusters
# 8 : 1
# 10 : 1
# 14 : 1
# 19 : 1
# 33 : 1
# 40 : 1
# 44 : 1
# 82 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000086/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000267
# #images : #clusters
# 23 : 1
# 55 : 1
# 58 : 1
# 114 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000267/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000178
# #images : #clusters
# 67 : 1
# 183 : 1
# #images in clusters total:  250
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000178/imagecluster/clusters
# /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000061
# #images : #clusters
# 4 : 2
# 6 : 1
# 7 : 1
# 8 : 1
# 9 : 1
# 10 : 2
# 17 : 2
# 19 : 1
# 20 : 1
# 21 : 1
# 43 : 1
# 54 : 1
# #images in clusters total:  249
# cluster dir: /mnt/disks/slow1/video_processing/frames/Luarent_data/81673/000061/imagecluster/clusters
